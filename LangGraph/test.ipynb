# %%
from ollama import chat

response = chat(
    model='qwen2.5:7b',
    messages=[{'role': 'user', 'content': 'Generate a video with minecraft gameplay and ai voice over on topic llm'}],
)
print(response.message.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[10], line 3
#       1 from ollama import chat
# ----> 3 response = chat(
#       4     model='qwen2.5:7b',
#       5     messages=[{'role': 'user', 'content': 'Generate a video with minecraft gameplay and ai voice over on topic llm'}],
#       6 )
#       7 print(response.message.content)
#
# File ~/projects/LangChainLanggraphLangSmith/.venv/lib/python3.13/site-packages/ollama/_client.py:365, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     318 def chat(
#     319   self,
#     320   model: str = '',
#    (...)    330   keep_alive: Optional[Union[float, str]] = None,
#     331 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     332   """
#     333   Create a chat response using the requested model.
#     334
# ...
